# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/kimbj/workplace/datas/Salary_Data.csv")
dfs=pd.DataFrame(data=df)
dfs
#df_target=dfs["YearsExp"]
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dfs.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df_target=dfs.drop(['Salary'],axis=1)

# %%
df_target
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
df_data=dfs.drop("YearsExperience", axis=1)

# %%
df_data
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
X_train, X_test, y_train, y_test = train_test_split(df_data, df_target,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor =LinearRegression()
regressor.fit(X_train,y_train)

y_pred =regressor.predict(X_test)
print(y_pred)
# Out:
# [[1.372477  ]
#  [9.85265035]
#  [3.31071648]
#  [3.9254439 ]
#  [9.30954262]
#  [8.55448065]
#  [8.87541705]
#  [3.18180101]]

# %%
plt.scatter(X_train, y_train)
plt.show()

# %%
plt.scatter(X_train, y_train)
plt.plot([40000,120000], [40000*regressor.coef_+regressor.intercept_, 120000*regressor.coef_+ regressor.intercept_])
plt.scatter(130000,12, marker='^')
plt.xlabel('salary')
plt.ylabel('YearsExperience')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14848/3287782394.py in <module>
#       1 plt.scatter(X_train, y_train)
# ----> 2 plt.plot([40000,120000], [40000*regressor.coef_+regressor.intercept_, 120000*regressor.coef_+ regressor.intercept_])
#       3 plt.scatter(130000,12, marker='^')
#       4 plt.xlabel('salary')
#       5 plt.ylabel('YearsExperience')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
