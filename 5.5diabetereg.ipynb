# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

data= pd.read_csv('C:/Users/kimbj/OneDrive/바탕 화면/김범진/가천 2학년 1학기/인공지능프로그래밍/diabetes.csv')
df=pd.DataFrame(data=data)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data=df.drop("Outcome", axis=1)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
data2=data.drop("BMI", axis=1)

# %%
data2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35        0
# 1              1       85             66             29        0
# 2              8      183             64              0        0
# 3              1       89             66             23       94
# 4              0      137             40             35      168
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 764            2      122             70             27        0
# 765            5      121             72             23      112
# 766            1      126             60              0        0
# 767            1       93             70             31        0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# ...

# %%
BMI=data["BMI"]

# %%
BMI
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
data = pd.concat([data2, BMI], axis=1)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35        0
# 1              1       85             66             29        0
# 2              8      183             64              0        0
# 3              1       89             66             23       94
# 4              0      137             40             35      168
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 764            2      122             70             27        0
# 765            5      121             72             23      112
# 766            1      126             60              0        0
# 767            1       93             70             31        0
#
#      DiabetesPedigreeFunction  Age   BMI
# 0                       0.627   50  33.6
# 1                       0.351   31  26.6
# 2                       0.672   32  23.3
# ...

# %%
X = data.iloc[:,0:7].values
y = data.iloc[:,7].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.   ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.   ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.   ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ..., 112.   ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.   ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.   ,   0.315,  23.   ]])

# %%
y
# Out:
# array([33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31. , 35.3, 30.5,  0. , 37.6,
#        38. , 27.1, 30.1, 25.8, 30. , 45.8, 29.6, 43.3, 34.6, 39.3, 35.4,
#        39.8, 29. , 36.6, 31.1, 39.4, 23.2, 22.2, 34.1, 36. , 31.6, 24.8,
#        19.9, 27.6, 24. , 33.2, 32.9, 38.2, 37.1, 34. , 40.2, 22.7, 45.4,
#        27.4, 42. , 29.7, 28. , 39.1,  0. , 19.4, 24.2, 24.4, 33.7, 34.7,
#        23. , 37.7, 46.8, 40.5, 41.5,  0. , 32.9, 25. , 25.4, 32.8, 29. ,
#        32.5, 42.7, 19.6, 28.9, 32.9, 28.6, 43.4, 35.1, 32. , 24.7, 32.6,
#        37.7, 43.2, 25. , 22.4,  0. , 29.3, 24.6, 48.8, 32.4, 36.6, 38.5,
#        37.1, 26.5, 19.1, 32. , 46.7, 23.8, 24.7, 33.9, 31.6, 20.4, 28.7,
#        49.7, 39. , 26.1, 22.5, 26.6, 39.6, 28.7, 22.4, 29.5, 34.3, 37.4,
#        33.3, 34. , 31.2, 34. , 30.5, 31.2, 34. , 33.7, 28.2, 23.2, 53.2,
#        34.2, 33.6, 26.8, 33.3, 55. , 42.9, 33.3, 34.5, 27.9, 29.7, 33.3,
#        34.5, 38.3, 21.1, 33.8, 30.8, 28.7, 31.2, 36.9, 21.1, 39.5, 32.5,
# ...

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD,Adam

# %%
def build_model(): 
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu',
                           input_shape=(7,)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model
model = build_model() 

model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_44 (Dense)            (None, 64)                512
#
#  dense_45 (Dense)            (None, 64)                4160
#
#  dense_46 (Dense)            (None, 1)                 65
#
# ...
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=10, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/10
# 20/20 [==============================] - 1s 14ms/step - loss: 223.7524 - mae: 9.1921 - val_loss: 34.8715 - val_mae: 4.5466
# Epoch 2/10
# 20/20 [==============================] - 0s 4ms/step - loss: 7.8243 - mae: 1.9553 - val_loss: 2.1640 - val_mae: 1.1659
# Epoch 3/10
# 20/20 [==============================] - 0s 7ms/step - loss: 6.2210 - mae: 1.8649 - val_loss: 4.8897 - val_mae: 1.9594
# Epoch 4/10
# 20/20 [==============================] - 0s 7ms/step - loss: 5.0579 - mae: 1.6258 - val_loss: 1.0065 - val_mae: 0.6757
# Epoch 5/10
# 20/20 [==============================] - 0s 4ms/step - loss: 4.3200 - mae: 1.3324 - val_loss: 0.6915 - val_mae: 0.6533
# Epoch 6/10
# 20/20 [==============================] - 0s 4ms/step - loss: 4.5077 - mae: 1.5368 - val_loss: 5.0567 - val_mae: 2.0383
# Epoch 7/10
# 20/20 [==============================] - 0s 4ms/step - loss: 3.8772 - mae: 1.3000 - val_loss: 1.9019 - val_mae: 1.1884
# Epoch 8/10
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5408 - mae: 0.6180
# [0.5407727956771851, 0.6179772019386292]
